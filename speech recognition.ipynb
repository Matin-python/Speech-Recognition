# %%
import speech_recognition as sr

# %%
r = sr.Recognizer()

voice = sr.AudioFile("tf.wav")
with voice as source:
    audio = r.record(source)
print(audio)
# Out:
# <speech_recognition.audio.AudioData object at 0x00000275A249F3B0>

# %%
text = r.recognize_google(audio)
print(text)

# %%
text = r.recognize_google(audio, language= 'fa-IR')
print(text)
# Out:
# سلام ۱۲۳ تست می‌کنیم که ببینیم فارسی متوجه میشه یا نه

# %%
r = sr.Recognizer()

with sr.Microphone() as source:
    r.pause_threshold = 1
    audio = r.listen(source)
print(audio)

text = r.recognize_google(audio)
print(text)
# Out:
# <speech_recognition.audio.AudioData object at 0x000001C9FD63D6D0>
# hi this test

# %%
r = sr.Recognizer()

with sr.Microphone() as source:
    r.pause_threshold = 1
    audio = r.listen(source)
print(audio)

text = r.recognize_google(audio, language= 'fa-IR')
print(text)
